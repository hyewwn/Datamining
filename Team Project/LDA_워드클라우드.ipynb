# %%
import pandas as pd
df= pd.read_csv('/content/drive/Shareddrives/데마팀플/🐯최종 파일_제출용/total_pos_w.token.csv')

# %%
df.columns = ['가게명','구', '리뷰내용', '긍정부정','단어','ㅇ']
df=df[['구','단어']]
df
# Out:
#           구                                                 단어
# 0       강남구        ['잘', '부드러워', '카레', '살짝', '짰', '맛있다', '먹다']
# 1       강남구                                      ['먹다', '맛있다']
# 2       강남구  ['필살기', '돈가스', '이후', '방문', '이제서야', '영수증', '리뷰'...
# 3       강남구  ['바삭', '튀김', '고기', '이중', '분리', '긴', '잘', '직원',...
# 4       강남구                                            ['맛있다']
# ...     ...                                                ...
# 254761  중랑구  ['달인', '사람', '꿋꿋이', '기다려', '간짜장', '맛', '짜장', '...
# 254762  중랑구  ['허름', '친절', '할아버지', '사장', '가격', '저렴', '정감', '...
# 254763  중랑구       ['할머니', '할아버지', '따듯', '정', '느낄', '자극', '좋다']
# 254764  중랑구        ['짬뽕', '국물', '깔끔', '가격', '기성', '가격', '올려도']
# 254765  중랑구                                            ['맛나다']
#
# [254766 rows x 2 columns]

# %%
# 그래프에서 한글표현을 위해 폰트를 설치합니다.
# %config InlineBackend.figure_format = 'retina'

# !apt -qq -y install fonts-nanum > /dev/null

#폰트
import matplotlib.font_manager as fm
fontpath = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
font = fm.FontProperties(fname=fontpath, size=9)
# Out:
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.

# %%
condition = (df['구']== '용산구')# 조건식 작성 #지역별로 뽑아내기
a=df[condition].reset_index()
a
# Out:
#        index    구                                                 단어
# 0     167385  용산구  ['오랜만', '추억', '떡볶이', '현선', '반반', '메뉴', '예전', '...
# 1     167386  용산구  ['쫄면', '사리', '추가', '중간', '맛', '매콤', '먹다', '먹다'...
# 2     167387  용산구      ['매운', '짝꿍', '지리', '매운맛', '겠어요', '맛있다', '먹다']
# 3     167388  용산구                        ['사장', '직원', '윽박질러서', '놀랬']
# 4     167389  용산구                                            ['맛있다']
# ...      ...  ...                                                ...
# 3417  247640  용산구              ['곱창', '차돌', '약밥', '곱창', '먹다', '맛있다']
# 3418  247641  용산구                 ['차돌박이', '염동', '너무나', '맛난', '비싸다']
# 3419  247642  용산구                                           ['정신없다']
# 3420  247643  용산구                                             ['최고']
# 3421  247644  용산구                                            ['맛나다']
#
# [3422 rows x 3 columns]

# %%
for i in range(len(a)):
  k=a['단어'][i].strip('['']')
  p=k.replace("'","")
  a['단어'][i]=p.replace(",","")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
a
# Out:
#         index    구                                                 단어
# 0           0  강남구                              잘 부드러워 카레 살짝 짰 맛있다 먹다
# 1           1  강남구                                             먹다 맛있다
# 2           2  강남구  필살기 돈가스 이후 방문 이제서야 영수증 리뷰 써요 가로수길 비슷비슷 음식 여긴 최...
# 3           3  강남구               바삭 튀김 고기 이중 분리 긴 잘 직원 친절 기분 점심 먹다 좋다
# 4           4  강남구                                                맛있다
# ...       ...  ...                                                ...
# 21098  222662  강남구                                             버거 괜찮다
# 21099  222663  강남구                                                 몰리
# 21100  222664  강남구   아보카도 버거 오리지널 프라이 콜라 햄버거 와우 평일 점심 대기 들어감 좋아하다 맛있다
# 21101  222665  강남구                               겁나 뉴욕 유학 시절 맛있다 생각나다
# 21102  222666  강남구                            치즈 버거 아보카도 버거 오리지널 프라이즈
#
# [21103 rows x 3 columns]

# %%
r1=[]
for i in range(len(a)):
  r1.append(a['단어'][i])

with open('b.txt','w',encoding='UTF-8') as f:
    for name in r1:
        f.write(name)

f = open('b.txt','r')
data = f.read()
f.close()

# %%
data
# Out:
# '오랜만 추억 떡볶이 현선 반반 메뉴 예전 매워 매운맛 먹다 먹다쫄면 사리 추가 중간 맛 매콤 먹다 먹다 맛있다매운 짝꿍 지리 매운맛 겠어요 맛있다 먹다사장 직원 윽박질러서 놀랬맛있다못난이 절반 튀김옷 떡볶이 반반 떡볶이 인분 섞다 맵다 팔다떡볶이 튀김 국물 떡볶이 기본 보통 매운맛 선택 가능 맛있다 좋다맛있다오랜 추억 떡집 방문 예전 거친 맛 맛 거칠다주문 퇴식 셀프 맛있다맛 기억 직원 친절 느낌 나쁘다떡볶이 당겨서 방문 금방 메뉴 준비 돼서 맛 종종 삼각지 근처 급하다 찾아보다 많다 좋다불친절 서비스 별로 비싼데 맛 잘 멀리 춥다 시끄럽다 적다 쓰다오랜만 실망 위생 떡볶이 스키 분과 열심히 대화 점심 장사 한창 활발 불구 매운맛 떡볶이 찐득 상태 맛 매운 맛 떡볶이 매운 맛 맛 입맛 있 맛 바뀐 이후 만드다 눌어붙다 짜다 매다 먹다 먹다오징어 튀김 드세요소문 이름값 못하 음식점 튀겼 해도 튀김 바짝 말라 맛 매운 떡볶이 캡사이신 매운맛 이외 맛 만든지 오래 터져 어제 만든 재고 데워 아닌가 생각 순대 온도 유지 있 미지근 상태 김밥 질겨 불편 붓다 더불다 파다 엄청나다 불다 파다 차갑다 약하다 씹다기대 봐요 보통배달 알림 소리 큽니다 주문 빨리 으셔서 아픕니다본즉 먹다 맛있다무난 맛 구성비 별로조미료 맛반반 맵다 섞다 먹다떡볶이 맛현선 맛나다옛날 맛 방문 했으나 실망 스러웠 그날 매운맛 매웠 시던 손님 반반 따로 말씀 느낀 생각 포장 떡볶이 남자 턱스 이야기 위생 코로나 시기 더더욱 조심 셔야 아닌가 생각 맛있다 먹다 생각나다 맵다 맵다 짜다 맵다 섞다 신나다많다 맛있다맛있다떡볶이 맛나다오랜만 방문 매장 리모 깨끗 떡볶이 일반 매운맛 매운맛 매운 생각 맛 맛있다떡볶이 국물 많다 좋다맛있다가격대 일반 주세요 추가 오버 가격 맛나다튀김 정말로 떡볶이 매운맛 매웠 맛있다봐야지 드디어 옛날 떡볶이 맛 추억 세트 메뉴 시켰 튀김 튀겨서 인지 따끈 나중 떠오르다 맛있다 맛있다 먹다현선 떡볶이 처음 칼칼 밀떡 꼬마 김밥 가격 떡볶이 가게 비해서 쪼금 맛 확실히 먹다
# ...

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

wordcloud=WordCloud(font_path='font/NanumGothic.ttf',background_color='white').generate(data)

plt.figure(figsize=(22,22))#이미지 사이즈 지정
plt.imshow(wordcloud,interpolation='lanczos')#이미지의 부드럽기 정도
plt.axis('off')#x y 축 숫자 제거
plt.show()
plt.savefig()
# Out:
# Output hidden; open in https://colab.research.google.com to view.
